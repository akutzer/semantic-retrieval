# %%
f = '../../data/fandoms/harry_potter.json'
import pandas as pd
df = pd.read_json(f, orient ='records')
df
# Out:
#           id     revid                                             url
# 0      21657  35050701  http://harrypotter.fandom.com/wiki?curid=21657  \
# 1      21660  39675822  http://harrypotter.fandom.com/wiki?curid=21660
# 2      21664  35050701  http://harrypotter.fandom.com/wiki?curid=21664
# 3      21665  49997385  http://harrypotter.fandom.com/wiki?curid=21665
# 4      21666  39675822  http://harrypotter.fandom.com/wiki?curid=21666
# ...      ...       ...                                             ...
# 17736   8213  23825763   http://harrypotter.fandom.com/wiki?curid=8213
# 17737   8214  35418795   http://harrypotter.fandom.com/wiki?curid=8214
# 17738   8215  35050701   http://harrypotter.fandom.com/wiki?curid=8215
# 17739   8218  35050701   http://harrypotter.fandom.com/wiki?curid=8218
# 17740   8220  26102182   http://harrypotter.fandom.com/wiki?curid=8220
#
#                            title
# 0               Jelly-Brain Jinx  \
# 1                 Intruder Charm
# 2              Bewitched tea set
# 3            Model of a Firebolt
# 4                       Snuffbox
# ...                          ...
# 17736                       Moke
# 17737                   Mooncalf
# 17738              Mooncalf dung
# 17739                    Murtlap
# 17740  Advanced Rune Translation
#
#                                                     text
# 0      [The Jelly-Brain Jinx was a jinx that reduced ...
# 1      [The Intruder Charm ("incantation unknown") wa...
# 2      [A bewitched tea set was owned by an old witch...
# 3      [A model of a Firebolt was a small working mod...
# 4      [A snuffbox is a decorative box originally int...
# ...                                                  ...
# 17736  [The Moke was a magical lizard with silver-gre...
# 17737  [The Mooncalf was a shy magical beast that onl...
# 17738  [Mooncalf dung could only be harvested when th...
# 17739  [The Murtlap was a magical marine beast resemb...
# 17740  [Advanced Rune Translation was a book about Ru...
#
# [17741 rows x 5 columns]

# %%
import json
import ast
f = 'harry_potter4.csv'
df_q = pd.read_csv(f)
df_q = df_q.sort_values(by=['i', 'j'], ascending=True)

arr = []
for list in df_q['positive'].values:
    try:
        arr.append(json.loads(list))
    except:
        try:
            arr.append(ast.literal_eval(list))
        except:
            print("fail")


arr2 = []
for list in df_q['negative'].values:
    try:
        arr2.append(json.loads(list))
    except:
        try:
            arr2.append(ast.literal_eval(list))
        except:
            print("fail")

i = 0
while i < len(arr):
    if len(arr[i]) == 3:
        arr2[i].append(arr[i].pop(-1))
    i = i + 1

df_q['negative'] = arr2
df_q['positive'] = arr 

df_q
# Out:
#          i  j                                           positive
# 83       0  0  [What does the Jelly-Brain Jinx do to a person...  \
# 130      0  1  [Which discipline in the wizarding world were ...
# 0        0  2  [What spell might have been used by the Death ...
# 51       1  1  [Who used a tracking charm on a Muggle-owned h...
# 81       2  0  [Who owned the bewitched tea set originally?, ...
# ...    ... ..                                                ...
# 2494  2029  0  [What is an animal ghost or spirit?, Who wrote...
# 2491  2030  0  [What are Beauxbatons horses also known as in ...
# 2496  2031  1  [What is the reason why many Dutch witches and...
# 2495  2031  2  [Who is a notable resident in the mentioned lo...
# 2497  2032  0  [What is the origin of the name Vulchanov or V...
#
#                                                negative
# 83    [Who created the Jelly-Brain Jinx?, How can on...  \
# 130   [Where can one find these gloves in the wizard...
# 0     [How did Ron manage to recover from the spell?...
# 51    [Whose Muggle-owned house did Horace Slughorn ...
# 81    [How did the old witch bewitch the tea set?, W...
# ...                                                 ...
# 2494  [Is it necessary for a dead creature to have m...
# 2491  [What is the origin of the Beauxbatons horses?...
# 2496  [Is Beauxbatons Academy of Magic the only opti...
# 2495  [What other notable residents are there in the...
# 2497  [What was the role of the Vulchanovs in the wi...
#
#                                                 passage
# 83    The Jelly-Brain Jinx was a jinx that reduced o...
# 130   [History] During the September 1999 riot that ...
# 0     [History] This spell might also have been the ...
# 51    [History] Horace Slughorn used it on a Muggle-...
# 81    A bewitched tea set was owned by an old witch,...
# ...                                                 ...
# 2494  An animal ghost, also known as an animal spiri...
# 2491  The Beauxbatons horses (French: "chevaux de Be...
# 2496  [Magical Education] Many Dutch witches and wiz...
# 2495  [Known residents] Notable residents include th...
# 2497  Vulchanov (or Vulchanova ) was the name of sev...
#
# [2498 rows x 5 columns]

# %%
df_q.iloc[1]['positive']
# Out:
# ['Which discipline in the wizarding world were these gloves particularly useful for?',
#  'What aspect of handling dangerous plants made these gloves highly practical?']

# %%
arr_base = []
for i in range(len(df)):
    arr = []
    l = len(df.iloc[i]['text'])
    for j in range(l):
        if df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)].empty:
            arr.append([])
        else:
            y = ([x for x in (df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)]['positive'].values)])
            arr.append(y[0])
    arr_base.append(arr)

df['positive'] = arr_base 


arr_base = []
for i in range(len(df)):
    arr = []
    l = len(df.iloc[i]['text'])
    for j in range(l):
        if df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)].empty:
            arr.append([])
        else:
            y = ([x for x in (df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)]['negative'].values)])
            arr.append(y[0])
    arr_base.append(arr)

df['negative'] = arr_base

# %%
df.to_json("harr_potter_q_a", orient='records', indent=4)
