# %%
f = '../../data/fandoms/harry_potter.json'
import pandas as pd
df = pd.read_json(f, orient ='records')
df
# Out:
#           id     revid                                             url
# 0      21657  35050701  http://harrypotter.fandom.com/wiki?curid=21657  \
# 1      21660  39675822  http://harrypotter.fandom.com/wiki?curid=21660
# 2      21664  35050701  http://harrypotter.fandom.com/wiki?curid=21664
# 3      21665  49997385  http://harrypotter.fandom.com/wiki?curid=21665
# 4      21666  39675822  http://harrypotter.fandom.com/wiki?curid=21666
# ...      ...       ...                                             ...
# 17736   8213  23825763   http://harrypotter.fandom.com/wiki?curid=8213
# 17737   8214  35418795   http://harrypotter.fandom.com/wiki?curid=8214
# 17738   8215  35050701   http://harrypotter.fandom.com/wiki?curid=8215
# 17739   8218  35050701   http://harrypotter.fandom.com/wiki?curid=8218
# 17740   8220  26102182   http://harrypotter.fandom.com/wiki?curid=8220
#
#                            title
# 0               Jelly-Brain Jinx  \
# 1                 Intruder Charm
# 2              Bewitched tea set
# 3            Model of a Firebolt
# 4                       Snuffbox
# ...                          ...
# 17736                       Moke
# 17737                   Mooncalf
# 17738              Mooncalf dung
# 17739                    Murtlap
# 17740  Advanced Rune Translation
#
#                                                     text
# 0      [The Jelly-Brain Jinx was a jinx that reduced ...
# 1      [The Intruder Charm ("incantation unknown") wa...
# 2      [A bewitched tea set was owned by an old witch...
# 3      [A model of a Firebolt was a small working mod...
# 4      [A snuffbox is a decorative box originally int...
# ...                                                  ...
# 17736  [The Moke was a magical lizard with silver-gre...
# 17737  [The Mooncalf was a shy magical beast that onl...
# 17738  [Mooncalf dung could only be harvested when th...
# 17739  [The Murtlap was a magical marine beast resemb...
# 17740  [Advanced Rune Translation was a book about Ru...
#
# [17741 rows x 5 columns]

# %%
import json
import ast
f2 = 'harry_potter_questions_a.csv'
df_q = pd.read_csv(f2)
df_q = df_q.sort_values(by=['i', 'j'], ascending=True)

arr = []
for list in df_q['positive'].values:
    try:
        arr.append(json.loads(list))
    except:
        try:
            arr.append(ast.literal_eval(list))
        except:
            print("fail")


arr2 = []
for list in df_q['negative'].values:
    try:
        arr2.append(json.loads(list))
    except:
        try:
            arr2.append(ast.literal_eval(list))
        except:
            print("fail")

            

i = 0
while i < len(arr):
    if len(arr[i]) == 3:
        arr2[i].append(arr[i].pop(-1))
    i = i + 1

df_q['negative'] = arr2
df_q['positive'] = arr 

arr = [len(x) for x in df_q['positive'].values]
print(len(arr))
print(arr.count(2))
#df_q
# Out:
# 20037
# 20036

# %%
pd.options.display.max_colwidth = 200
df_q.head()
# Out:
#        i  j
# 14723  1  0  \
# 16912  2  0
# 19356  4  3
# 4154   5  0
# 7676   7  0
#
#                                                                                                                                                       positive
# 14723                                                         [What is the purpose of the Intruder Charm?, Do we know the incantation for the Intruder Charm?]  \
# 16912                                      [What happened to the tea set after the old witch died? , Who sorted out the situation with the bewitched tea set?]
# 19356  [How did the idea of "Behind the scenes" originate and who introduced it to Europe?, When did the use of snuff become popular and among which classes?]
# 4154     [Which Hogwarts house did one of the MacDougal family members get sorted into?, What kind of family was the MacDougal family in the wizarding world?]
# 7676                                                     [What is a life debt and how is it formed?, Can a life debt be avoided or ignored once it is formed?]
#
#                                                                                                                                                               negative
# 14723                                                                                            [How does the Intruder Charm work?, Who invented the Intruder Charm?]  \
# 16912                     [What were the consequences of the tea set being sold to the Muggle antique shop?, How did the old witch come to own the bewitched tea set?]
# 19356  [Are there any other countries or regions where "Behind the scenes" originated or became popular?, What is the meaning of "Behind the scenes" in this context?]
# 4154                     [Can you name any famous or notable members of the MacDougal family?, In which era did the MacDougal family flourish in the wizarding world?]
# 7676                                [Is there a limit to how long a life debt can last?, In what specific situations would someone owe a life debt to another person?]
#
#                                                                                                                                                                                                        passage
# 14723                                                         The Intruder Charm ("incantation unknown") was a charm which detected intruders and sounded an alarm, the magical-equivalent to a burglar alarm.
# 16912  A bewitched tea set was owned by an old witch, until she died and the tea set was sold to a Muggle antique shop. It was subsequently purchased by a Muggle woman who used it for a tea party, but th...
# 19356  [Behind the scenes] originated in the Americas, being first recorded among the indigenous people of Brazil. The idea was brought to Europe by friar Ramón Pané, who had observed the practice on 's ...
# 4154                                                                     MacDougal was the surname of a pure-blood wizarding family. At least one of its members was known to have been Sorted into Ravenclaw.
# 7676   A life debt was a magical bond formed between a wizard or witch and the person whose life they saved. The one who owed the debt to the saviour would one day be obliged to repay the deed by doing s...

# %%
arr_base = []
for i in range(len(df)):
    arr = []
    l = len(df.iloc[i]['text'])
    for j in range(l):
        if df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)].empty:
            arr.append([])
        else:
            y = ([x for x in (df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)]['positive'].values)])
            arr.append(y[0])
    arr_base.append(arr)

df['positive'] = arr_base 


arr_base = []
for i in range(len(df)):
    arr = []
    l = len(df.iloc[i]['text'])
    for j in range(l):
        if df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)].empty:
            arr.append([])
        else:
            y = ([x for x in (df_q.loc[(df_q['i'] == i) & (df_q['j'] == j)]['negative'].values)])
            arr.append(y[0])
    arr_base.append(arr)

df['negative'] = arr_base

# %%
print(df.iloc[8]['text'])
print(df.iloc[8]['positive'])
# Out:
# ['The wand of Filius Flitwick was of unknown length, wood and core material.', '[History] Like most wizards and witches in Great Britain, he may have purchased it at the age of eleven at Ollivanders before beginning his education at Hogwarts School of Witchcraft and Wizardry.', '[History] In December 1991, Flitwick used this wand to decorate Christmas trees with golden bubbles.', "[History] In March of 1996, Flitwick used this wand to cast a Locomotion Charm on Sybill Trelawney's two trunks and help escort her back into the castle after Dolores Umbridge fired her.", '[History] He was able to perform outstanding magic with his wand such as performing advanced charms, and duelling many wizards in his time.', '[History] It had an angular cross-shaped handle and was made of a light wood with a deep brown tint toward the end.']
# [["Which aspects of Filius Flitwick's wand are unknown?", "What is the material of Filius Flitwick's wand not mentioned in the passage?"], ['At what age might a wizard or witch in Great Britain purchase a wand at Ollivanders?', 'What is the typical course of action for a wizard or witch before beginning their education at Hogwarts School of Witchcraft and Wizardry?'], ['When did Flitwick use this wand to decorate Christmas trees with golden bubbles?', 'What was the purpose of using this wand in December 1991?'], ['When did Flitwick cast the Locomotion Charm using this wand?', 'Who did Flitwick help escort back into the castle after she was fired by Dolores Umbridge?'], [], []]

# %%
pd.options.display.max_colwidth = 400
df.head(5)
# Out:
#       id     revid                                             url
# 0  21657  35050701  http://harrypotter.fandom.com/wiki?curid=21657  \
# 1  21660  39675822  http://harrypotter.fandom.com/wiki?curid=21660
# 2  21664  35050701  http://harrypotter.fandom.com/wiki?curid=21664
# 3  21665  49997385  http://harrypotter.fandom.com/wiki?curid=21665
# 4  21666  39675822  http://harrypotter.fandom.com/wiki?curid=21666
#
#                  title
# 0     Jelly-Brain Jinx  \
# 1       Intruder Charm
# 2    Bewitched tea set
# 3  Model of a Firebolt
# 4             Snuffbox
#
#                                                                                                                                                                                                                                                                                                                                                                                                               text
# 0     [The Jelly-Brain Jinx was a jinx that reduced one's mental abilities., [History] During the September 1999 riot that took place in the middle of the Puddlemere United versus Holyhead Harpies Quidditch game, many of the Harpy supporters were using this jinx., [History] This spell might also have been the spell that the Death Eaters hit Ron with during the Battle of the Department of Mysteries.]  \
# 1                                      [The Intruder Charm ("incantation unknown") was a charm which detected intruders and sounded an alarm, the magical-equivalent to a burglar alarm., [History] Horace Slughorn used it on a Muggle-owned house he stayed in temporarily in 1996 in Budleigh Babberton, but did not hear it go off when Albus Dumbledore and Harry Potter arrived because he was in the bath.]
# 2  [A bewitched tea set was owned by an old witch, until she died and the tea set was sold to a Muggle antique shop. It was subsequently purchased by a Muggle woman who used it for a tea party, but the bewitched tea set caused it to end in disaster and several injuries; the teapot went berserk and squirted boiling tea everywhere and one unfortunate man ended up hospitalised when the sugar tongs a...
# 3                                                                 [A model of a Firebolt was a small working model of the world-class Firebolt. Harry Potter received one of these at Christmas from Nymphadora Tonks on 25 December 1995. Harry missed his real Firebolt which he got back at the end of the year while watching it zoom around his bedroom at 12 Grimmauld Place during the Christmas holidays.]
# 4  [A snuffbox is a decorative box originally intended to hold snuff, a form of powdered tobacco inhaled through the nose., [History] At the end of the 1991–1992 school year at Hogwarts School of Witchcraft and Wizardry, first-years had to transform a mouse into a snuffbox for their Transfiguration exam. Points were granted for the snuffbox's prettiness, but points were deducted if the snuffboxes...
#
#                                                                                                                                                                 positive
# 0                                                                                                                                                           [[], [], []]  \
# 1                                                                 [[What is the purpose of the Intruder Charm?, Do we know the incantation for the Intruder Charm?], []]
# 2                                                  [[What happened to the tea set after the old witch died? , Who sorted out the situation with the bewitched tea set?]]
# 3                                                                                                                                                                   [[]]
# 4  [[], [], [], [How did the idea of "Behind the scenes" originate and who introduced it to Europe?, When did the use of snuff become popular and among which classes?]]
#
#                                                                                                                                                                         negative
# 0                                                                                                                                                                   [[], [], []]
# 1                                                                                                    [[How does the Intruder Charm work?, Who invented the Intruder Charm?], []]
# 2                                 [[What were the consequences of the tea set being sold to the Muggle antique shop?, How did the old witch come to own the bewitched tea set?]]
# 3                                                                                                                                                                           [[]]
# 4  [[], [], [], [Are there any other countries or regions where "Behind the scenes" originated or became popular?, What is the meaning of "Behind the scenes" in this context?]]

# %%
pd.options.display.max_colwidth = 50
df
# Out:
#           id     revid                                             url
# 0      21657  35050701  http://harrypotter.fandom.com/wiki?curid=21657  \
# 1      21660  39675822  http://harrypotter.fandom.com/wiki?curid=21660
# 2      21664  35050701  http://harrypotter.fandom.com/wiki?curid=21664
# 3      21665  49997385  http://harrypotter.fandom.com/wiki?curid=21665
# 4      21666  39675822  http://harrypotter.fandom.com/wiki?curid=21666
# ...      ...       ...                                             ...
# 17736   8213  23825763   http://harrypotter.fandom.com/wiki?curid=8213
# 17737   8214  35418795   http://harrypotter.fandom.com/wiki?curid=8214
# 17738   8215  35050701   http://harrypotter.fandom.com/wiki?curid=8215
# 17739   8218  35050701   http://harrypotter.fandom.com/wiki?curid=8218
# 17740   8220  26102182   http://harrypotter.fandom.com/wiki?curid=8220
#
#                            title
# 0               Jelly-Brain Jinx  \
# 1                 Intruder Charm
# 2              Bewitched tea set
# 3            Model of a Firebolt
# 4                       Snuffbox
# ...                          ...
# 17736                       Moke
# 17737                   Mooncalf
# 17738              Mooncalf dung
# 17739                    Murtlap
# 17740  Advanced Rune Translation
#
#                                                     text
# 0      [The Jelly-Brain Jinx was a jinx that reduced ...  \
# 1      [The Intruder Charm ("incantation unknown") wa...
# 2      [A bewitched tea set was owned by an old witch...
# 3      [A model of a Firebolt was a small working mod...
# 4      [A snuffbox is a decorative box originally int...
# ...                                                  ...
# 17736  [The Moke was a magical lizard with silver-gre...
# 17737  [The Mooncalf was a shy magical beast that onl...
# 17738  [Mooncalf dung could only be harvested when th...
# 17739  [The Murtlap was a magical marine beast resemb...
# 17740  [Advanced Rune Translation was a book about Ru...
#
#                                                 positive
# 0                                           [[], [], []]  \
# 1      [[What is the purpose of the Intruder Charm?, ...
# 2      [[What happened to the tea set after the old w...
# 3                                                   [[]]
# 4      [[], [], [], [How did the idea of "Behind the ...
# ...                                                  ...
# 17736  [[], [What is the maximum length the Moke coul...
# 17737                   [[], [], [], [], [], [], [], []]
# 17738  [[When is the only time that mooncalf dung can...
# 17739  [[What is the Murtlap's physical appearance?, ...
# 17740  [[What is Advanced Rune Translation?, What cou...
#
#                                                 negative
# 0                                           [[], [], []]
# 1      [[How does the Intruder Charm work?, Who inven...
# 2      [[What were the consequences of the tea set be...
# 3                                                   [[]]
# 4      [[], [], [], [Are there any other countries or...
# ...                                                  ...
# 17736  [[], [In which location(s) can the Moke be fou...
# 17737                   [[], [], [], [], [], [], [], []]
# 17738  [[How long do mooncalves stay above ground dur...
# 17739  [[How does the Murtlap interact with other mag...
# 17740  [[Who wrote the book Advanced Rune Translation...
#
# [17741 rows x 7 columns]

# %%
df.to_json("harr_potter_q_a", orient='records', indent=4)
df2 = df.copy()
df2.columns
# Out:
# Index(['id', 'revid', 'url', 'title', 'text', 'positive', 'negative'], dtype='object')

# %%
queries = []
qids = []
pids = []
pid_wid = []
passages = []
qid_id = 0
pid_id = 0
triples = []
wikis = []
inconsistent = 0

for i in range(len(df2)):
    row = df.iloc[i]
    wiki_pids = []

    for j in range(len(row['text'])):
        pids.append(pid_id)
        passages.append(row['text'][j])
        pid_wid.append(row['id'])
        wiki_pids.append(pid_id)

        pid_id = pid_id + 1


        if len(row['positive'][j]) != len(row['negative'][j]):
            inconsistent = inconsistent + 1
        for k in range(min(len(row['positive'][j]), len(row['negative'][j]))):
            queries.append(row['positive'][j][k])
            qids.append(qid_id)
            qid_id = qid_id + 1


            queries.append(row['negative'][j][k])
            qids.append(qid_id)
            qid_id = qid_id + 1
            triples.append(( qid_id - 2, qid_id - 1,pid_id - 1))
    wikis.append(wiki_pids)

print(inconsistent)
# Out:
# 59

# %%
df2 = df2.drop(['text', 'positive', 'negative'], axis=1)

# %%
pid_p_df = pd.DataFrame(zip(pids,passages, pid_wid),columns=['PID', 'passage', 'WID'])
qid_q_df = pd.DataFrame(zip(qids,queries),columns=['QID', 'query'])
triples_df = pd.DataFrame(triples,columns=['QID+', 'QID-', 'PID'])
df2['PIDs'] = wikis

# %%
triples_df.head(3)
# Out:
#    QID+  QID-  PID
# 0     0     1    3
# 1     2     3    3
# 2     4     5    5

# %%
pid_p_df.head(4)
# Out:
#    PID                                            passage    WID
# 0    0  The Jelly-Brain Jinx was a jinx that reduced o...  21657
# 1    1  [History] During the September 1999 riot that ...  21657
# 2    2  [History] This spell might also have been the ...  21657
# 3    3  The Intruder Charm ("incantation unknown") was...  21660

# %%
qid_q_df.head(6)
# Out:
#    QID                                              query
# 0    0         What is the purpose of the Intruder Charm?
# 1    1                  How does the Intruder Charm work?
# 2    2  Do we know the incantation for the Intruder Ch...
# 3    3                   Who invented the Intruder Charm?
# 4    4  What happened to the tea set after the old wit...
# 5    5  What were the consequences of the tea set bein...

# %%
triples_df.head(3)
# Out:
#    QID+  QID-  PID
# 0     0     1    3
# 1     2     3    3
# 2     4     5    5

# %%
df2.head(3)
# Out:
#       id     revid                                             url
# 0  21657  35050701  http://harrypotter.fandom.com/wiki?curid=21657  \
# 1  21660  39675822  http://harrypotter.fandom.com/wiki?curid=21660
# 2  21664  35050701  http://harrypotter.fandom.com/wiki?curid=21664
#
#                title       PIDs
# 0   Jelly-Brain Jinx  [0, 1, 2]
# 1     Intruder Charm     [3, 4]
# 2  Bewitched tea set        [5]

# %%
import json
output_path = "./temp/"
triples_df.to_csv(output_path+ "triples.tsv",index=False, sep="\t")
pid_p_df.to_csv(output_path+ "passages.tsv",index=False, sep="\t")
qid_q_df.to_csv(output_path+ "queries.tsv",index=False, sep="\t")

data = df2.to_dict('index')

# convert the dictionary to the desired JSON format
output = {}
for key, value in data.items():
    output[value['id']] = {
        'revid': value['revid'],
        'url': value['url'],
        'title': value['title'],
        'PIDs': value['PIDs']
    }

# convert the output dictionary to JSON
# json_output = json.dumps(output)
with open(output_path + 'wiki.json', 'w') as f:
    json.dump(output, f, indent=4)
